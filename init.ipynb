# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting tikzplotlib==0.10.1
#   Downloading tikzplotlib-0.10.1-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 KB 11.6 MB/s eta 0:00:00
# Collecting pysurvival==0.1.2
#   Downloading pysurvival-0.1.2.tar.gz (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 88.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pandas_profiling==3.2.0
#   Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.6/262.6 KB 43.2 MB/s eta 0:00:00
# Collecting lifelines
#   Downloading lifelines-0.27.0-py3-none-any.whl (349 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.1/349.1 KB 50.9 MB/s eta 0:00:00
# Collecting webcolors
#   Downloading webcolors-1.12-py3-none-any.whl (9.9 kB)
# Requirement already satisfied: matplotlib>=1.4.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from tikzplotlib==0.10.1->-r ./requirements.txt (line 1)) (3.5.2)
# Requirement already satisfied: numpy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from tikzplotlib==0.10.1->-r ./requirements.txt (line 1)) (1.21.6)
# Requirement already satisfied: Pillow in /shared-libs/python3.7/py/lib/python3.7/site-packages (from tikzplotlib==0.10.1->-r ./requirements.txt (line 1)) (9.1.1)
# Requirement already satisfied: pandas in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pysurvival==0.1.2->-r ./requirements.txt (line 2)) (1.2.5)
# Requirement already satisfied: pip in /root/venv/lib/python3.7/site-packages (from pysurvival==0.1.2->-r ./requirements.txt (line 2)) (22.0.4)
# Collecting progressbar
#   Downloading progressbar-2.5.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pyarrow in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pysurvival==0.1.2->-r ./requirements.txt (line 2)) (8.0.0)
# Requirement already satisfied: scikit-learn in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pysurvival==0.1.2->-r ./requirements.txt (line 2)) (1.0.2)
# Requirement already satisfied: scipy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pysurvival==0.1.2->-r ./requirements.txt (line 2)) (1.7.3)
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: torch in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pysurvival==0.1.2->-r ./requirements.txt (line 2)) (1.11.0)
# Collecting htmlmin>=0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pydantic>=1.8.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas_profiling==3.2.0->-r ./requirements.txt (line 3)) (1.8.2)
# Collecting phik>=0.11.1
#   Downloading phik-0.12.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (690 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 690.3/690.3 KB 51.4 MB/s eta 0:00:00
# Collecting markupsafe~=2.1.1
#   Downloading MarkupSafe-2.1.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting visions[type_image_path]==0.7.4
#   Downloading visions-0.7.4-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.4/102.4 KB 21.5 MB/s eta 0:00:00
# Requirement already satisfied: joblib~=1.1.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas_profiling==3.2.0->-r ./requirements.txt (line 3)) (1.1.0)
# Collecting multimethod>=1.4
#   Downloading multimethod-1.8-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: jinja2>=2.11.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pandas_profiling==3.2.0->-r ./requirements.txt (line 3)) (2.11.3)
# Requirement already satisfied: requests>=2.24.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas_profiling==3.2.0->-r ./requirements.txt (line 3)) (2.27.1)
# Requirement already satisfied: seaborn>=0.10.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas_profiling==3.2.0->-r ./requirements.txt (line 3)) (0.11.2)
# Collecting missingno>=0.4.2
#   Downloading missingno-0.5.1-py3-none-any.whl (8.7 kB)
# Collecting tangled-up-in-unicode==0.2.0
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 83.7 MB/s eta 0:00:00
# Collecting PyYAML>=5.0.0
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.3/596.3 KB 50.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.48.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas_profiling==3.2.0->-r ./requirements.txt (line 3)) (4.64.0)
# Requirement already satisfied: attrs>=19.3.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling==3.2.0->-r ./requirements.txt (line 3)) (21.4.0)
# Collecting networkx>=2.4
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 71.7 MB/s eta 0:00:00
# Collecting imagehash
#   Downloading ImageHash-4.2.1.tar.gz (812 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.6/812.6 KB 58.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting formulaic>=0.2.2
#   Downloading formulaic-0.3.4-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.2/68.2 KB 16.3 MB/s eta 0:00:00
# Collecting autograd>=1.3
#   Downloading autograd-1.4-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 KB 8.9 MB/s eta 0:00:00
# Collecting autograd-gamma>=0.3
#   Downloading autograd-gamma-0.5.0.tar.gz (4.0 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: future>=0.15.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from autograd>=1.3->lifelines->-r ./requirements.txt (line 4)) (0.18.2)
# Collecting astor>=0.8
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: wrapt>=1.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from formulaic>=0.2.2->lifelines->-r ./requirements.txt (line 4)) (1.14.1)
# Collecting interface-meta<2.0.0,>=1.2.0
#   Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=1.4.0->tikzplotlib==0.10.1->-r ./requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=1.4.0->tikzplotlib==0.10.1->-r ./requirements.txt (line 1)) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=1.4.0->tikzplotlib==0.10.1->-r ./requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=1.4.0->tikzplotlib==0.10.1->-r ./requirements.txt (line 1)) (4.33.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=1.4.0->tikzplotlib==0.10.1->-r ./requirements.txt (line 1)) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib>=1.4.0->tikzplotlib==0.10.1->-r ./requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas->pysurvival==0.1.2->-r ./requirements.txt (line 2)) (2022.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pydantic>=1.8.1->pandas_profiling==3.2.0->-r ./requirements.txt (line 3)) (4.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests>=2.24.0->pandas_profiling==3.2.0->-r ./requirements.txt (line 3)) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests>=2.24.0->pandas_profiling==3.2.0->-r ./requirements.txt (line 3)) (2022.5.18.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests>=2.24.0->pandas_profiling==3.2.0->-r ./requirements.txt (line 3)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests>=2.24.0->pandas_profiling==3.2.0->-r ./requirements.txt (line 3)) (3.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-learn->pysurvival==0.1.2->-r ./requirements.txt (line 2)) (3.1.0)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->tikzplotlib==0.10.1->-r ./requirements.txt (line 1)) (1.16.0)
# Collecting PyWavelets
#   Downloading PyWavelets-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 85.0 MB/s eta 0:00:00
# Building wheels for collected packages: pysurvival, autograd-gamma, htmlmin, progressbar, sklearn, imagehash
#   Building wheel for pysurvival (setup.py): started
#   Building wheel for pysurvival (setup.py): finished with status 'done'
#   Created wheel for pysurvival: filename=pysurvival-0.1.2-cp37-cp37m-linux_x86_64.whl size=1108879 sha256=041803f8127b3cad6a57cbc779e4bb8ead20183772e71cead9e320abdd93de0e
#   Stored in directory: /root/.cache/pip/wheels/1a/63/e2/32273d765a4e2f4ccac69c8adf97425ca80bab5d0c8447f120
#   Building wheel for autograd-gamma (setup.py): started
#   Building wheel for autograd-gamma (setup.py): finished with status 'done'
#   Created wheel for autograd-gamma: filename=autograd_gamma-0.5.0-py3-none-any.whl size=4034 sha256=6787c4ac8c61f24e7d20491403a1b3dd0f04deed2c19b86cf218fe434fceda8b
#   Stored in directory: /root/.cache/pip/wheels/9f/01/ee/1331593abb5725ff7d8c1333aee93a50a1c29d6ddda9665c9f
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27085 sha256=4e5fa6566b8e832a782687b94ec75e5388c5e591be29a96fa2fc542a15ebbd6a
#   Stored in directory: /root/.cache/pip/wheels/70/e1/52/5b14d250ba868768823940c3229e9950d201a26d0bd3ee8655
#   Building wheel for progressbar (setup.py): started
#   Building wheel for progressbar (setup.py): finished with status 'done'
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12074 sha256=11929a9a0e542c77b3593ca7d0e8742ef6b94ae0b323ae945b49b3c0b411f682
#   Stored in directory: /root/.cache/pip/wheels/f0/fd/1f/3e35ed57e94cd8ced38dd46771f1f0f94f65fec548659ed855
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=e1ede581fa7c3bbb8179761f602f5e4277333f41821e2018cc9da868fe77de34
#   Stored in directory: /root/.cache/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
#   Building wheel for imagehash (setup.py): started
#   Building wheel for imagehash (setup.py): finished with status 'done'
#   Created wheel for imagehash: filename=ImageHash-4.2.1-py2.py3-none-any.whl size=295198 sha256=6eca232aa65202d20935bfcf57f31a793d7c318646056ba049340be2efb04e46
#   Stored in directory: /root/.cache/pip/wheels/4c/d5/59/5e3e297533ddb09407769762985d134135064c6831e29a914e
# Successfully built pysurvival autograd-gamma htmlmin progressbar sklearn imagehash
# Installing collected packages: progressbar, htmlmin, webcolors, tangled-up-in-unicode, PyYAML, PyWavelets, networkx, multimethod, markupsafe, interface-meta, autograd, astor, imagehash, autograd-gamma, visions, tikzplotlib, sklearn, phik, formulaic, pysurvival, missingno, lifelines, pandas_profiling
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 2.0.1
#     Not uninstalling markupsafe at /shared-libs/python3.7/py-core/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'MarkupSafe'. No files were found to uninstall.
# Successfully installed PyWavelets-1.3.0 PyYAML-6.0 astor-0.8.1 autograd-1.4 autograd-gamma-0.5.0 formulaic-0.3.4 htmlmin-0.1.12 imagehash-4.2.1 interface-meta-1.3.0 lifelines-0.27.0 markupsafe-2.1.1 missingno-0.5.1 multimethod-1.8 networkx-2.6.3 pandas_profiling-3.2.0 phik-0.12.2 progressbar-2.5 pysurvival-0.1.2 sklearn-0.0 tangled-up-in-unicode-0.2.0 tikzplotlib-0.10.1 visions-0.7.4 webcolors-1.12
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy 3.3.1 requires typing-extensions<4.2.0,>=3.7.4; python_version < "3.8", but you have typing-extensions 4.2.0 which is incompatible.
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=5b875ec7-933b-4a3a-92bc-cefd5e08f9f6' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
